# %% [markdown]
# <a href="https://colab.research.google.com/github/BlueDracoZ/Plataformas-de-anal-tica-de-negocios-para-organizaciones-Andre-Ramirez/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importamos librerias
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# MARCA

# %%
#Definimos 2 arreglos de dimensión 100
ys = 200 + np.random.randn(100)
x = np.arange (0, 100, 1)

# %%
#Graficamos los arreglos en un plano 2D
plt.plot(x,ys,'-')
plt.fill_between(x,ys,195,where=(ys>195),facecolor='gold',alpha=1)
#agregamos titulo a la grafica
plt.title("Sample Visualization")
plt.xlabel("eje de las x",size=16,)
plt.ylabel("eje de las y",size=16,)
plt.show()
